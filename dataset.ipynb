# %%
from google.colab import drive
import pandas as pd
import glob
import os

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#merging all female/male tweets in 1 csv

path=(r'/content/gdrive/MyDrive/Spring2022/gender-detection/tweets/male/')

# path=(r'\content\gdrive\MyDrive\Spring2022\gender-detection\tweets\female')
# print(os.path.join(path , "*.csv"))
all_files = glob.glob(os.path.join(path , "*.csv"))

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

m_frame = pd.concat(li, axis=0, ignore_index=True)
len(m_frame)
# Out:
# 49762

# %%
path=(r'/content/gdrive/MyDrive/Spring2022/gender-detection/tweets/female/')
f_files = glob.glob(os.path.join(path , "*.csv"))
li_f = []

for filename in f_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li_f.append(df)

frame = pd.concat(li_f, axis=0, ignore_index=True)
len(frame)
# Out:
# 49757

# %%
#shuffling the dataframes
frame['label']='Female'
m_frame['label']='Male'
# m_df = m_frame.sample(frac=1).reset_index(drop=True)
# f_df = frame.sample(frac=1).reset_index(drop=True)

#-------------train------------

frames = [frame, m_frame]
result = pd.concat(frames)
#shuffling the dataframe
result_train = result.sample(frac=1).reset_index(drop=True)
result_train
# Out:
#                 twitter_id                       date  \
# 0       408837851497775104  2013-12-06 05:58:34+00:00
# 1       564594677601427457  2015-02-09 01:20:35+00:00
# 2      1453675710367817728  2021-10-28 10:51:11+00:00
# 3       415917762020933632  2013-12-25 18:51:36+00:00
# 4      1505915021464940554  2022-03-21 14:31:34+00:00
# ...                    ...                        ...
# 99514  1317135140456263685  2020-10-16 16:07:43+00:00
# 99515  1265451080420220928  2020-05-27 01:13:43+00:00
# 99516   417160348374822912  2013-12-29 05:09:12+00:00
# 99517   561679349275820033  2015-02-01 00:16:07+00:00
# 99518   405488513480548352  2013-11-27 00:09:29+00:00
#
#                                                    tweet   label
# 0      b'Loving the makeover Maria! (You tart) #Sound...  Female
# 1       b'Anna Kendrick looks hot. No bra. Well played.'    Male
# 2      b'\xf0\x9f\x94\x91\xf0\x9f\x94\x91\xf0\x9f\x94...  Female
# 3      b'the photo booth was a big hit last night \xf...  Female
# 4      b'Titans\xe2\x80\x99 free-agent linebacker Ras...    Male
# ...                                                  ...     ...
# 99514  b'A year in the making, @SKIMS Velour is my mo...  Female
# 99515                     b'FAM https://t.co/RHDz5wZJr3'  Female
# 99516           b'.@MarioLopezExtra hope you had fun ;)'  Female
# 99517  b'RT @natgilmore: Soo blessed and grateful to ...    Male
# 99518  b'.@ETonlineAlert @wondersterek I love chocola...  Female
#
# [99519 rows x 4 columns]

# %%
# result_train.groupby(['label']).size()
#writing dataframes to csv files
result_train.to_csv('/content/gdrive/MyDrive/Spring2022/gender-detection/tweets/train_2.csv')

# %%
result_train.drop(['twitter_id', 'date'], axis=1, inplace=True)
result_train
# Out:
#                                                    tweet   label
# 0      b'Loving the makeover Maria! (You tart) #Sound...  Female
# 1       b'Anna Kendrick looks hot. No bra. Well played.'    Male
# 2      b'\xf0\x9f\x94\x91\xf0\x9f\x94\x91\xf0\x9f\x94...  Female
# 3      b'the photo booth was a big hit last night \xf...  Female
# 4      b'Titans\xe2\x80\x99 free-agent linebacker Ras...    Male
# ...                                                  ...     ...
# 99514  b'A year in the making, @SKIMS Velour is my mo...  Female
# 99515                     b'FAM https://t.co/RHDz5wZJr3'  Female
# 99516           b'.@MarioLopezExtra hope you had fun ;)'  Female
# 99517  b'RT @natgilmore: Soo blessed and grateful to ...    Male
# 99518  b'.@ETonlineAlert @wondersterek I love chocola...  Female
#
# [99519 rows x 2 columns]
